# %% [markdown]
# # runed

# %%
from lovely_docs.settings import settings, GitSource
from lovely_docs.git import clone_repo
from lovely_docs.docs import (
    build_markdown_doc_tree, process_tree_depth_first, calculate_total_usage, calculate_cost,
    save_processed_documents
)
import logging

# %%
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

# %% [markdown]
# #### Clone the repo

# %%
source = GitSource(
    name="runed",
    doc_dir="sites/docs/src/content",
    repo="https://github.com/svecosystem/runed",
    commit="main",
    ecosystems=["svelte"]
)

commit, clone_dir = clone_repo(source)
source.commit = commit  # Replace the literal commit (master) with the hash

# %% [markdown]
# #### Read the markdown files

# %%
tree = build_markdown_doc_tree(clone_dir / source.doc_dir, extensions=['.md'])

# %%
processed_tree = await process_tree_depth_first(settings, tree, source.name)
# Out:
# +0.897s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/active-element.md
# +0.260s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/animation-frames.md
# +0.019s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/bool-attr.md
# +0.019s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/context.md
# +0.016s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/debounced.md
# +0.016s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/element-rect.md
# +0.019s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/element-size.md
# +0.016s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/extract.md
# +0.017s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/finite-state-machine.md
# +0.017s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/is-document-visible.md
# +0.017s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/is-focus-within.md
# +0.016s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/is-idle.md
# +0.016s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/is-in-viewport.md
# +0.016s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/is-mounted.md
# +0.016s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/on-cleanup.md
# +0.019s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/on-click-outside.md
# +0.016s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/persisted-state.md
# +0.019s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/pressed-keys.md
# +0.019s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/previous.md
# +0.018s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/resource.md
# +0.018s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/scroll-state.md
# +0.019s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/state-history.md
# +0.017s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/textarea-autosize.md
# +0.018s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/throttled.md
# +0.018s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/use-debounce.md
# +0.020s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/use-event-listener.md
# +0.019s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/use-geolocation.md
# +0.017s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/use-intersection-observer.md
# +0.020s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/use-interval.md
# +0.017s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/use-mutation-observer.md
# +0.021s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/use-resize-observer.md
# +0.020s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/use-search-params.md
# +0.023s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/use-throttle.md
# +0.020s DEBUG lovely_docs/docs.py:157 llm_process_page Processing utilities/watch.md
# +31.209s DEBUG lovely_docs/docs.py:259 llm_process_directory Processing utilities
# +22.924s DEBUG lovely_docs/docs.py:157 llm_process_page Processing getting-started.md
# +0.016s DEBUG lovely_docs/docs.py:157 llm_process_page Processing index.md
# +4.003s DEBUG lovely_docs/docs.py:259 llm_process_directory Processing .

# %%
usage = calculate_total_usage(processed_tree)
print(f"\nTotal Usage:")
print(f"  Input tokens: {usage.input:,}")
print(f"  Output tokens: {usage.output:,}")
print(f"  Total tokens: {(usage.input + usage.output):,}")

cost, input_cost, output_cost = calculate_cost(usage, 1, 5)

print(f"Cost:")
print(f"  Total: ${cost:.2f}")
print(f"  Input: ${input_cost:.2f}")
print(f"  Output: ${output_cost:.2f}")
# Out:
# Total Usage:
#   Input tokens: 93,523
#   Output tokens: 27,664
#   Total tokens: 121,187
# Cost:
#   Total: $0.23
#   Input: $0.09
#   Output: $0.14

# %%
save_processed_documents(source, settings.output_dir / source.name.replace("/", "_"), processed_tree)
