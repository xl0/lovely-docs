# %% [markdown]
# # nunjucks

# %%
from lovely_docs.settings import settings, GitSource
from lovely_docs.git import clone_repo
from lovely_docs.docs import (
    build_markdown_doc_tree,
    process_tree_depth_first,
    calculate_total_usage,
    calculate_cost,
    save_processed_documents,
)

from pathlib import Path
from datetime import datetime
import logging

# %%
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

# %%
source = GitSource(
    name="daytona",
    doc_dir="apps/docs/src/content/docs/en",
    repo="https://github.com/daytonaio/daytona",
    commit="main",
    ecosystems=["js", "python"],
)

commit, clone_dir = clone_repo(source)
source.commit = commit

# %%
tree = build_markdown_doc_tree(clone_dir / source.doc_dir, extensions=['.mdx'])

# %%
extra_dir="For directories that are language-specific (python, js, go, etc), include the language name in the dir name"

processed_tree = await process_tree_depth_first(settings, tree, source.name, extra_dir=extra_dir)
# Out:
# +2.135s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing go-sdk/daytona.mdx
# +0.294s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing go-sdk/errors.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing go-sdk/index.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing go-sdk/options.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing go-sdk/types.mdx
# +0.018s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/computer-use.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/config.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/daytona.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/file-system.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/git.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/image.mdx
# +0.018s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/index.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/lsp-server.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/object-storage.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/process.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/sandbox.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/snapshot.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/volume-service.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ruby-sdk/volume.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing tools/api.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing tools/cli.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/charts.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/code-interpreter.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/computer-use.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/daytona.mdx
# +0.020s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/errors.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/execute-response.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/file-system.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/git.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/image.mdx
# +0.022s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/index.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/lsp-server.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/object-storage.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/process.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/pty-handle.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/pty.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/sandbox.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/snapshot.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing typescript-sdk/volume.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/claude/claude-agent-sdk-connect-service-sandbox.mdx
# +0.025s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/claude/claude-agent-sdk-interactive-terminal-sandbox.mdx
# +0.024s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/claude/claude-code-run-cli-sandbox.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/claude/claude-code-run-tasks-stream-logs-sandbox.mdx
# +0.024s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/claude/index.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/rlm/dspy-rlms.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/rlm/index.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/rlm/recursive-language-models.mdx
# +0.018s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/async/async-code-interpreter.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/async/async-computer-use.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/async/async-daytona.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/async/async-file-system.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/async/async-git.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/async/async-lsp-server.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/async/async-object-storage.mdx
# +0.019s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/async/async-process.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/async/async-sandbox.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/async/async-snapshot.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/async/async-volume.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/common/charts.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/common/errors.mdx
# +0.019s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/common/image.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/sync/code-interpreter.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/sync/computer-use.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/sync/daytona.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/sync/file-system.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/sync/git.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/sync/lsp-server.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/sync/object-storage.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/sync/process.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/sync/sandbox.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/sync/snapshot.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/sync/volume.mdx
# +12.773s DEBUG preprocessor/nbs/lovely_docs/docs.py:262 llm_process_directory Processing python-sdk/common
# +0.486s DEBUG preprocessor/nbs/lovely_docs/docs.py:262 llm_process_directory Processing tools
# +6.756s DEBUG preprocessor/nbs/lovely_docs/docs.py:262 llm_process_directory Processing ruby-sdk
# +1.417s DEBUG preprocessor/nbs/lovely_docs/docs.py:262 llm_process_directory Processing guides/claude
# +0.870s DEBUG preprocessor/nbs/lovely_docs/docs.py:262 llm_process_directory Processing guides/rlm
# +0.153s DEBUG preprocessor/nbs/lovely_docs/docs.py:262 llm_process_directory Processing python-sdk/sync
# +0.820s DEBUG preprocessor/nbs/lovely_docs/docs.py:262 llm_process_directory Processing typescript-sdk
# +2.932s DEBUG preprocessor/nbs/lovely_docs/docs.py:262 llm_process_directory Processing python-sdk/async
# +16.270s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/agentkit/inngest-agentkit-coding-agent.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/codex/codex-sdk-interactive-terminal-sandbox.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/data-analysis-with-ai.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/google-adk-code-generator.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/index.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/langchain/langchain-data-analysis.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/letta-code/letta-code-agent.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/mastra/mastra-coding-agent.mdx
# +0.020s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/openclaw/openclaw-run-secure-sandbox.mdx
# +0.019s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/opencode/opencode-web-agent.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing guides/reinforcement-learning/trl-grpo-training.mdx
# +0.457s DEBUG preprocessor/nbs/lovely_docs/docs.py:262 llm_process_directory Processing go-sdk
# +12.002s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing python-sdk/index.mdx
# +6.301s DEBUG preprocessor/nbs/lovely_docs/docs.py:262 llm_process_directory Processing python-sdk
# +17.527s DEBUG preprocessor/nbs/lovely_docs/docs.py:262 llm_process_directory Processing guides
# +109.788s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing api-keys.mdx
# +0.018s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing audit-logs.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing billing.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing computer-use.mdx
# +0.014s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing configuration.mdx
# +0.018s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing custom-domain-authentication.mdx
# +0.014s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing declarative-builder.mdx
# +0.013s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing experimental/otel-collection.mdx
# +0.014s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing file-system-operations.mdx
# +0.014s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing getting-started.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing git-operations.mdx
# +0.014s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing index.mdx
# +0.014s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing language-server-protocol.mdx
# +0.014s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing limits.mdx
# +0.014s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing linked-accounts.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing log-streaming.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing mcp.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing network-limits.mdx
# +0.014s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing organizations.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing oss-deployment.mdx
# +0.014s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing playground.mdx
# +0.014s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing preview.mdx
# +0.014s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing process-code-execution.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing pty.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing regions.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing runners.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing sandboxes.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing snapshots.mdx
# +0.015s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing ssh-access.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing vnc-access.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing volumes.mdx
# +0.017s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing vpn-connections.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing web-terminal.mdx
# +0.016s DEBUG preprocessor/nbs/lovely_docs/docs.py:156 llm_process_page Processing webhooks.mdx
# +51.908s DEBUG preprocessor/nbs/lovely_docs/docs.py:262 llm_process_directory Processing .

# %%
usage = calculate_total_usage(processed_tree)
cost, input_cost, output_cost = calculate_cost(usage, 1, 5)

print(f"\nTotal Usage:")
print(f"  Input tokens: {usage.input:,}")
print(f"  Output tokens: {usage.output:,}")
print(f"  Total tokens: {(usage.input + usage.output):,}")
print(f"Cost:")
print(f"  Total: ${cost:.2f}")
print(f"  Input: ${input_cost:.2f}")
print(f"  Output: ${output_cost:.2f}")
# Out:
# Total Usage:
#   Input tokens: 752,556
#   Output tokens: 226,102
#   Total tokens: 978,658
# Cost:
#   Total: $1.88
#   Input: $0.75
#   Output: $1.13

# %%
# processed_tree.children[0].name = "nunjucks"
# processed_tree.children[0].displayName = "Nunjucks"

# %%
save_processed_documents(
    source, settings.output_dir / source.name.replace("/", "_"), processed_tree
)
